# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# read the data
data = pd.read_csv('df_clean.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17803 entries, 0 to 17802
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   LeagueCountry             17803 non-null  object
#  1   League                    17803 non-null  object
#  2   NationalLeagueLevel       17803 non-null  object
#  3   Club                      17803 non-null  object
#  4   No                        17494 non-null  float64
#  5   Name                      17803 non-null  object
#  6   Value                     17803 non-null  float64
#  7   HighestValue              17803 non-null  float64
#  8   Age                       17800 non-null  float64
#  9   Height                    16713 non-null  float64
#  10  Nationality               17803 non-null  object
#  11  Foot                      16118 non-null  object
#  12  Position                  17803 non-null  object
# ...

# %%
df_float = data.select_dtypes(include='float')

# %%
for col in df_float.columns:
    sns.jointplot(data=df_float, x='Value', y=col, kind="reg")
    plt.show()

# %%
df = pd.DataFrame(data)

# %%
Consultancies = df["Consultancy"].value_counts().nlargest(5).index

# %%
filtered_df = df[df["Consultancy"].isin(Consultancies)]

# %%
sns.boxplot(x=filtered_df["Value"], y=filtered_df["Consultancy"])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Consultancy'>

# %%
sns.boxplot(x=df["Value"], y=df["Foot"])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Foot'>

# %%
sns.boxplot(x=df["Value"], y=df["Position"])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Position'>

# %%
Nationality = df["Nationality"].value_counts().nlargest(10).index

# %%
filtered_df_2 = df[df["Nationality"].isin(Nationality)]

# %%
sns.boxplot(x=filtered_df_2["Value"], y=filtered_df_2["Nationality"])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Nationality'>

# %%
Supplier = df["Supplier"].value_counts().nlargest(5).index

# %%
filtered_df_3 = df[df["Supplier"].isin(Supplier)]

# %%
sns.boxplot(x=filtered_df_3["Value"], y=filtered_df_3["Supplier"])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Supplier'>
